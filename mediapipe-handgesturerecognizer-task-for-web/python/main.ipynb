# %%
import mediapipe as mp
import cv2
import numpy as np
from datetime import datetime

# %%
class DetectedGesture:
    def __init__(self) -> None:
        self.category_name = None
        self.start_time = None
        self.end_time = None

BaseOptions = mp.tasks.BaseOptions
GestureRecognizer = mp.tasks.vision.GestureRecognizer
GestureRecognizerOptions = mp.tasks.vision.GestureRecognizerOptions
VisionRunningMode = mp.tasks.vision.RunningMode

# Create a gesture recognizer instance with the video mode:
options = GestureRecognizerOptions(
    base_options=BaseOptions(model_asset_path='../assets/gesture_recognizer.task'),
    running_mode=VisionRunningMode.VIDEO)

# Use OpenCV’s VideoCapture to load the input video.
cap = cv2.VideoCapture('../assets/hand_gesture.mp4')

# Load the frame rate of the video using OpenCV’s CV_CAP_PROP_FPS
# You’ll need it to calculate the timestamp for each frame.
fps = cap.get(cv2.CAP_PROP_FPS)

time_stamp_ms = 0
recognizer = GestureRecognizer.create_from_options(options)
current_gesture = DetectedGesture()
all_gestures = []

start_time = datetime.now()
while cap.isOpened():
    # Read the frame from OpenCV’s VideoCapture.
    success, frame = cap.read()

    # Break out of the loop if there are no more frames.
    if not success:
        break

    # Convert the frame to RGB using OpenCV’s cvtColor().
    # rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Convert the frame to a numpy array using OpenCV’s asarray().
    numpy_frame_from_opencv = np.asarray(frame)

    # Convert the frame received from OpenCV to a MediaPipe’s Image object.
    mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=numpy_frame_from_opencv)

    # Process the image using the gesture recognizer.
    results = recognizer.recognize_for_video(mp_image, time_stamp_ms)

    # Print the gesture label and the timestamp of the frame.
    if results.gestures:
        gesture_name = results.gestures[0][0].category_name
        
        if not current_gesture.start_time:
            current_gesture.start_time = time_stamp_ms
            current_gesture.category_name = gesture_name
        
        if current_gesture.category_name != gesture_name:
            all_gestures.append(current_gesture)
            current_gesture = DetectedGesture()
        
        current_gesture.end_time = time_stamp_ms
        print(f'{gesture_name} at {time_stamp_ms / 1000} s')
    
    time_stamp_ms += round(1000 / fps)

all_gestures.append(current_gesture)

print(f'Elapsed time: {datetime.now() - start_time}')
# Out:
# Open_Palm at 0.924 s
# Open_Palm at 0.957 s
# Open_Palm at 0.99 s
# Open_Palm at 1.023 s
# Open_Palm at 1.056 s
# Open_Palm at 1.089 s
# Open_Palm at 1.122 s
# Open_Palm at 1.155 s
# Open_Palm at 1.188 s
# Open_Palm at 1.221 s
# Open_Palm at 1.254 s
# Open_Palm at 1.287 s
# Open_Palm at 1.32 s
# Open_Palm at 1.353 s
# Open_Palm at 1.386 s
# Open_Palm at 1.419 s
# Open_Palm at 1.452 s
# Open_Palm at 1.485 s
# Open_Palm at 1.518 s
# Open_Palm at 1.551 s
# Open_Palm at 1.584 s
# Open_Palm at 1.617 s
# Open_Palm at 1.65 s
# Open_Palm at 1.683 s
# Open_Palm at 1.716 s
# Open_Palm at 1.749 s
# Open_Palm at 1.782 s
# Open_Palm at 1.815 s
# Open_Palm at 1.848 s
# Open_Palm at 1.881 s
# Open_Palm at 1.914 s
# Open_Palm at 1.947 s
# Open_Palm at 1.98 s
# Open_Palm at 2.013 s
# Open_Palm at 2.046 s
# Open_Palm at 2.079 s
# Open_Palm at 2.112 s
# Open_Palm at 2.145 s
# Open_Palm at 2.178 s
# None at 2.211 s
# None at 2.244 s
# Closed_Fist at 2.277 s
# Closed_Fist at 2.31 s
# Closed_Fist at 2.343 s
# Closed_Fist at 2.376 s
# Closed_Fist at 2.409 s
# Closed_Fist at 2.442 s
# Closed_Fist at 2.475 s
# Closed_Fist at 2.508 s
# Closed_Fist at 2.541 s
# Closed_Fist at 2.574 s
# Closed_Fist at 2.607 s
# Closed_Fist at 2.64 s
# Closed_Fist at 2.673 s
# Closed_Fist at 2.706 s
# Closed_Fist at 2.739 s
# Closed_Fist at 2.772 s
# Closed_Fist at 2.805 s
# Closed_Fist at 2.838 s
# Closed_Fist at 2.871 s
# Closed_Fist at 2.904 s
# Closed_Fist at 2.937 s
# Closed_Fist at 2.97 s
# Closed_Fist at 3.003 s
# Closed_Fist at 3.036 s
# Closed_Fist at 3.069 s
# Closed_Fist at 3.102 s
# Closed_Fist at 3.135 s
# Closed_Fist at 3.168 s
# Closed_Fist at 3.201 s
# Closed_Fist at 3.234 s
# Closed_Fist at 3.267 s
# Closed_Fist at 3.3 s
# Closed_Fist at 3.333 s
# Closed_Fist at 3.366 s
# Closed_Fist at 3.399 s
# Closed_Fist at 3.432 s
# Closed_Fist at 3.465 s
# Closed_Fist at 3.498 s
# Closed_Fist at 3.531 s
# Closed_Fist at 3.564 s
# Closed_Fist at 3.597 s
# None at 3.63 s
# None at 3.663 s
# Victory at 3.696 s
# Victory at 3.729 s
# Victory at 3.762 s
# Victory at 3.795 s
# Victory at 3.828 s
# Victory at 3.861 s
# Victory at 3.894 s
# Victory at 3.927 s
# Victory at 3.96 s
# Victory at 3.993 s
# Victory at 4.026 s
# Victory at 4.059 s
# Victory at 4.092 s
# Victory at 4.125 s
# Victory at 4.158 s
# Victory at 4.191 s
# Victory at 4.224 s
# Victory at 4.257 s
# Victory at 4.29 s
# Victory at 4.323 s
# Victory at 4.356 s
# Victory at 4.389 s
# Victory at 4.422 s
# Victory at 4.455 s
# Victory at 4.488 s
# Victory at 4.521 s
# Victory at 4.554 s
# Victory at 4.587 s
# Victory at 4.62 s
# Victory at 4.653 s
# Victory at 4.686 s
# Victory at 4.719 s
# Victory at 4.752 s
# Victory at 4.785 s
# Victory at 4.818 s
# Victory at 4.851 s
# Victory at 4.884 s
# Victory at 4.917 s
# Victory at 4.95 s
# None at 4.983 s
# None at 5.016 s
# ILoveYou at 5.049 s
# ILoveYou at 5.082 s
# ILoveYou at 5.115 s
# ILoveYou at 5.148 s
# ILoveYou at 5.181 s
# ILoveYou at 5.214 s
# ILoveYou at 5.247 s
# ILoveYou at 5.28 s
# ILoveYou at 5.313 s
# ILoveYou at 5.346 s
# ILoveYou at 5.379 s
# ILoveYou at 5.412 s
# ILoveYou at 5.445 s
# ILoveYou at 5.478 s
# ILoveYou at 5.511 s
# ILoveYou at 5.544 s
# ILoveYou at 5.577 s
# ILoveYou at 5.61 s
# ILoveYou at 5.643 s
# ILoveYou at 5.676 s
# ILoveYou at 5.709 s
# ILoveYou at 5.742 s
# ILoveYou at 5.775 s
# ILoveYou at 5.808 s
# ILoveYou at 5.841 s
# ILoveYou at 5.874 s
# ILoveYou at 5.907 s
# ILoveYou at 5.94 s
# ILoveYou at 5.973 s
# ILoveYou at 6.006 s
# ILoveYou at 6.039 s
# ILoveYou at 6.072 s
# ILoveYou at 6.105 s
# ILoveYou at 6.138 s
# ILoveYou at 6.171 s
# ILoveYou at 6.204 s
# ILoveYou at 6.237 s
# ILoveYou at 6.27 s
# ILoveYou at 6.303 s
# ILoveYou at 6.336 s
# ILoveYou at 6.369 s
# ILoveYou at 6.402 s
# ILoveYou at 6.435 s
# ILoveYou at 6.468 s
# ILoveYou at 6.501 s
# ILoveYou at 6.534 s
# ILoveYou at 6.567 s
# ILoveYou at 6.6 s
# ILoveYou at 6.633 s
# ILoveYou at 6.666 s
# ILoveYou at 6.699 s
# ILoveYou at 6.732 s
# ILoveYou at 6.765 s
# ILoveYou at 6.798 s
# ILoveYou at 6.831 s
# ILoveYou at 6.864 s
# ILoveYou at 6.897 s
# ILoveYou at 6.93 s
# ILoveYou at 6.963 s
# ILoveYou at 6.996 s
# ILoveYou at 7.029 s
# ILoveYou at 7.062 s
# ILoveYou at 7.095 s
# ILoveYou at 7.128 s
# ILoveYou at 7.161 s
# ILoveYou at 7.194 s
# ILoveYou at 7.227 s
# ILoveYou at 7.26 s
# ILoveYou at 7.293 s
# ILoveYou at 7.326 s
# ILoveYou at 7.359 s
# None at 7.392 s
# None at 7.425 s
# None at 7.458 s
# None at 7.491 s
# None at 7.524 s
# None at 7.557 s
# None at 7.59 s
# Thumb_Down at 7.623 s
# Thumb_Down at 7.656 s
# Thumb_Down at 7.689 s
# Thumb_Down at 7.722 s
# Thumb_Down at 7.755 s
# Thumb_Down at 7.788 s
# Thumb_Down at 7.821 s
# Thumb_Down at 7.854 s
# Thumb_Down at 7.887 s
# Thumb_Down at 7.92 s
# Thumb_Down at 7.953 s
# Thumb_Down at 7.986 s
# Thumb_Down at 8.019 s
# Thumb_Down at 8.052 s
# Thumb_Down at 8.085 s
# Thumb_Down at 8.118 s
# Thumb_Down at 8.151 s
# Thumb_Down at 8.184 s
# Thumb_Down at 8.217 s
# Thumb_Down at 8.25 s
# Thumb_Down at 8.283 s
# Thumb_Down at 8.316 s
# Thumb_Down at 8.349 s
# Thumb_Down at 8.382 s
# Thumb_Down at 8.415 s
# Thumb_Down at 8.448 s
# Thumb_Down at 8.481 s
# Thumb_Down at 8.514 s
# Thumb_Down at 8.547 s
# Thumb_Down at 8.58 s
# Thumb_Down at 8.613 s
# Thumb_Down at 8.646 s
# Thumb_Down at 8.679 s
# Thumb_Down at 8.712 s
# Thumb_Down at 8.745 s
# Thumb_Down at 8.778 s
# Thumb_Down at 8.811 s
# None at 8.844 s
# Closed_Fist at 8.877 s
# Closed_Fist at 8.91 s
# Closed_Fist at 8.943 s
# Closed_Fist at 8.976 s
# Closed_Fist at 9.009 s
# Closed_Fist at 9.042 s
# Elapsed time: 0:00:05.812490

# %%
for gesture in all_gestures:
    print(f'{gesture.category_name} from {gesture.start_time / 1000} s to {gesture.end_time / 1000} s')
# Out:
# Open_Palm from 0.924 s to 2.178 s
# None from 2.244 s to 2.244 s
# Closed_Fist from 2.31 s to 3.597 s
# None from 3.663 s to 3.663 s
# Victory from 3.729 s to 4.95 s
# None from 5.016 s to 5.016 s
# ILoveYou from 5.082 s to 7.359 s
# None from 7.425 s to 7.59 s
# Thumb_Down from 7.656 s to 8.811 s
# Closed_Fist from 8.877 s to 9.042 s
